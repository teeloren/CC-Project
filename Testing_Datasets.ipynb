# %% [markdown]
# <a href="https://colab.research.google.com/github/teeloren/CC-Project/blob/main/Testing_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt

# %%
#possible datasets
#https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/Broadband_Availability_By_Municipality.csv
#https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/City_of_Albany_Building_Permits_Issued___2009-2013.csv
#https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/2005-2010-graduation-outcomes-by-borough.csv
#https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/Farmers__Markets_in_New_York_State_Map.csv
#https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/number-of-deaths-by-risk-factor.csv

datasets = {
    'Name': ['Grad Outcomes', 'Broadband', 'Permits', 'Markets', 'Risk Factors'],
    'Rows': [385, 1635,11837,381,6468],
    'Cols': [22,24,10,20,31],
    'Float Cols': [11,1,1,2,29],
    'Int Cols': [8,19,3,2,1],
    'Obj Cols': [3,4,6,16,1],
}
df = pd.DataFrame(datasets)
df['% Num'] = ((df['Float Cols'] + df['Int Cols'])/(df['Float Cols'] + df['Int Cols']+df['Obj Cols']))*100
df
# Out:
#             Name   Rows  Cols  Float Cols  Int Cols  Obj Cols      % Num
# 0  Grad Outcomes    385    22          11         8         3  86.363636
# 1      Broadband   1635    24           1        19         4  83.333333
# 2        Permits  11837    10           1         3         6  40.000000
# 3        Markets    381    20           2         2        16  20.000000
# 4   Risk Factors   6468    31          29         1         1  96.774194

# %%
df = pd.read_csv('https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/2005-2010-graduation-outcomes-by-borough.csv')

df.head()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/Broadband_Availability_By_Municipality.csv')

df.head()
# Out:
#    GNIS ID Municipality Name Municipality Type  2010 Muni Population  \
# 0   978655             Adams              Town                  5143
# 1   942159             Adams           Village                  1775
# 2   978656           Addison              Town                  2595
# 3   942177           Addison           Village                  1763
# 4   978657             Afton              Town                  2851
#
#    2010 Muni Housing Units  Muni Area (sq mi)     County  \
# 0                     2126               42.4  Jefferson
# 1                      793                1.5  Jefferson
# 2                     1159               25.7    Steuben
# 3                      770                1.9    Steuben
# 4                     1457               46.7   Chenango
#
#             REDC Region  # Cable Providers  # Hse Units Cable  ...  \
# 0  North Country Region                  1               1800  ...
# 1  North Country Region                  1                760  ...
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/City_of_Albany_Building_Permits_Issued___2009-2013.csv')

df.head()
# Out:
#          Date  Application Number  Permit Number                Address  \
# 0  12/31/2013             68411.0          55999  128 South Swan Street
# 1  12/31/2013             68529.0          56000     800 Central Avenue
# 2  12/31/2013             68547.0          56006       18 Mohican Place
# 3  12/31/2013             68484.0          56001   49-51 Erie Boulevard
# 4  12/31/2013             68546.0          56005      18 Oakwood Street
#
#                   Owner                   Contractor  Estimated Cost  Fee  \
# 0  395 Washington, LLC       Skyland Services, Inc.            88000    0
# 1      800 Central, LLC  New York Light Energy, LLC            66900    0
# 2        Amanda Bingel     CR Gas Logs & Fireplaces             2300    0
# 3   Global Partners, LP              Mackie Electric           26000    0
# 4        Honor Conklin      Phillips Home Solutions             1200    0
#
#                                  Description of Work  \
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/Farmers__Markets_in_New_York_State_Map.csv')

df.head()
# Out:
#    County                               Market Name  \
# 0  Albany              Altamont Orchards Farm Stand
# 1  Albany    Empire State Plaza Wed Farmers' Market
# 2  Albany              New Covenant Farmers' Market
# 3  Albany                  The Gade Farm Farm Stand
# 4  Albany  Veggie Mobile-Arbor Hill/Oak Street Park
#
#                                      Market Location  \
# 0                      6654 Dunnsville Road Altamont
# 1  Empire State Plaza, (Winter inside South Conco...
# 2  New Covenant Presbyterian Church, 916 Western ...
# 3                       2479 Western Avenue Altamont
# 4                  Oak Street & Second Street Albany
#
#                Address Line 1      City State    Zip           Contact  \
# 0        6654 Dunnsville Road  Altamont    NY  12009    Jim Abbruzzese
# 1                170 State St    Albany    NY  12210  Nicholas DeBlois
# 2             916 Western Ave    Albany    NY  12203       Katy Stenta
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/teeloren/CC-Project/main/datasets/number-of-deaths-by-risk-factor.csv')

df.head()
# Out:
#         Entity  Year  Unsafe water source  Unsafe sanitation  \
# 0  Afghanistan  1990          7554.049543        5887.747628
# 1  Afghanistan  1991          7359.676749        5732.770160
# 2  Afghanistan  1992          7650.437822        5954.804987
# 3  Afghanistan  1993         10270.731380        7986.736613
# 4  Afghanistan  1994         11409.177110        8863.010065
#
#    No access to handwashing facility  \
# 0                        5412.314513
# 1                        5287.891103
# 2                        5506.657363
# 3                        7104.620351
# 4                        8051.515953
#
#    Household air pollution from solid fuels  Non-exclusive breastfeeding  \
# 0                               22388.49723                  3221.138842
# 1                               22128.75821                  3150.559597
# 2                               22873.76879                  3331.349048
# 3                               25599.75628                  4477.006100
# ...
